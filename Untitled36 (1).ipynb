# %%
import pandas as pd

import requests


url = "https://instagram-scraper-api2.p.rapidapi.com/v1/info"

querystring = {"username_or_id_or_url":"mrbeast"}

headers = {
	"x-rapidapi-key": "4ec21c2fecmsh14df5f241257405p16b2b4jsn6e5cf27cf78f",
	"x-rapidapi-host": "instagram-scraper-api2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data_1=response.json()
df=pd.DataFrame(data_1)
print(df)
# Out:
#                                                                 data
# about                                                           None
# account_badges                                                    []
# account_type                                                       3
# active_standalone_fundraisers  {'fundraisers': [], 'total_count': 0}
# adjusted_banners_order                                            []
# ...                                                              ...
# show_shoppable_feed                                            False
# third_party_downloads_enabled                                      1
# total_igtv_videos                                                  1
# upcoming_events                                                   []
# username                                                     mrbeast
#
# [72 rows x 1 columns]

# %%
df.to_csv('data_1.csv', index= False)
from google.colab import files

files.download('data_1.csv')

# %% [markdown]
# **Changing the bio-links into new dataframe.**

# %%
x=df['data'][8]
df1=pd.DataFrame(x)
print(df1)
df1["open_external_url_with_in_app_browser"]
# Out:
#   image_url  is_pinned  is_verified            link_id link_type  \
# 0                False        False  17961115826140065  external
#
#                                             lynx_url  \
# 0  https://l.instagram.com/?u=http%3A%2F%2Ffeasta...
#
#    open_external_url_with_in_app_browser title                    url
# 0                                   True        http://feastables.com
# 0    True
# Name: open_external_url_with_in_app_browser, dtype: bool

# %%
#  making copy of df1

df1_copy = df1.copy()
df1_copy
# Out:
#   image_url  is_pinned  is_verified            link_id link_type  \
# 0                False        False  17961115826140065  external
#
#                                             lynx_url  \
# 0  https://l.instagram.com/?u=http%3A%2F%2Ffeasta...
#
#    open_external_url_with_in_app_browser title                    url
# 0                                   True        http://feastables.com

# %%
# prompt: replace column name 'open_external_url_with_in_app_browser' by 'external_url'

df1.rename(columns={'open_external_url_with_in_app_browser': 'external_url'}, inplace=True)

# %% [markdown]
# **Changing biography_with_entities column into new dataframe.**

# %%
y= df['data'][11]
y
# Out:
# {'entities': [{'user': {'id': 9947671186, 'username': 'feastables'}}],
#  'raw_text': 'Go to your local Walmart, 7/11, Target, and Speedway in America to try @feastables you’ll love it'}

# %%
user = {'id': 9947671186, 'username': 'feastables'}

# Convert the dictionary to a DataFrame
df4 = pd.DataFrame(user, index=[0])

df4
# Out:
#            id    username
# 0  9947671186  feastables

# %%
## Renaming column name id to user_id from user table

df4.rename(columns={"id": "user_id"}, inplace= True)
df4
# Out:
#       user_id    username
# 0  9947671186  feastables

# %% [markdown]
# **Changing column hd_profile_pic_url_info into dataframe.**

# %%
z=df['data'][32]
df5=pd.DataFrame(z, index=[0])
# print(df5)
df5
# Out:
#    height                                                url  width
# 0     500  https://scontent-dfw5-2.cdninstagram.com/v/t51...    500

# %%
# renaming url to profile_pic_url in df5 :-

df5.rename(columns={"url": "profile_pic_url"}, inplace= True)
df5
# Out:
#    height                                    profile_pic_url  width
# 0     500  https://scontent-hou1-1.cdninstagram.com/v/t51...    500

# %% [markdown]
# **Changing column hd_profile_pic_versions into new dataframe df6:-**

# %%
a=df['data'][33]
df6=pd.DataFrame(a, index=[0])
# print(df5)
df6
# Out:
#    height                                                url  width
# 0     320  https://scontent-dfw5-2.cdninstagram.com/v/t51...    320

# %%
# renaming url to profile_pic_url_versions in df6 :-

df6.rename(columns={"url": "profile_pic_url_versions"}, inplace= True)
df6
# Out:
#    height                           profile_pic_url_versions  width
# 0     500  https://scontent-hou1-1.cdninstagram.com/v/t51...    500

# %% [markdown]
# **Changing column location_data into new dataframe df7 :-**

# %%
b=df['data'][49]
df7=pd.DataFrame(b, index=[0])
# print(df5)
df7
# Out:
#   address_street  city_id city_name instagram_location_id  latitude  \
# 0                       0                                       0.0
#
#    longitude zip
# 0        0.0

# %% [markdown]
# **Checking null values:-**

# %%
# extract the null value from cloumn 'data' in df

df[df['data'].isnull()]
# Out:
#                                data
# about                          None
# ads_incentive_expiration_date  None
# ads_page_id                    None
# ads_page_name                  None
# biography_email                None
# current_catalog_id             None
# page_id                        None
# page_name                      None

# %%
# replace null value to NAN

df.fillna('NAN', inplace=True)
df.head(20)
# Out:
#                                                                                data
# about                                                                           NAN
# account_badges                                                                   []
# account_type                                                                      3
# active_standalone_fundraisers                 {'fundraisers': [], 'total_count': 0}
# adjusted_banners_order                                                           []
# ads_incentive_expiration_date                                                   NAN
# ads_page_id                                                                     NAN
# ads_page_name                                                                   NAN
# bio_links                         [{'image_url': '', 'is_pinned': False, 'is_ver...
# biography                         Go to your local Walmart, 7/11, Target, and Sp...
# ...

# %% [markdown]
# **Fetching the rows having value 'True' and 'False in column name 'data' in df**

# %%
df[df['data'].isin([True, False])]
# Out:
#                                          data
# can_add_fb_group_link_on_profile        False
# can_hide_category                        True
# can_hide_public_contacts                 True
# eligible_for_text_app_activation_badge  False
# has_anonymous_profile_picture           False
# has_chaining                             True
# has_guides                              False
# has_igtv_series                         False
# is_business                             False
# is_call_to_action_enabled               False
# is_category_tappable                    False
# is_eligible_for_request_message         False
# is_favorite                             False
# is_favorite_for_clips                   False
# is_favorite_for_igtv                    False
# is_favorite_for_stories                 False
# is_parenting_account                    False
# is_private                              False
# is_profile_audio_call_enabled           False
# ...

# %%
# Checking rows having link only :-

d=df.iloc[[22,61,62]]['data']
d
# Out:
# external_lynx_url     https://l.instagram.com/?u=http%3A%2F%2Ffeasta...
# profile_pic_url       https://scontent-hou1-1.cdninstagram.com/v/t51...
# profile_pic_url_hd    https://scontent-hou1-1.cdninstagram.com/v/t51...
# Name: data, dtype: object

# %% [markdown]
# **Converting all rows having links only into new dtaframe df8:-**

# %%
df8=pd.DataFrame(d)
df8
# Out:
#                                                                  data
# external_lynx_url   https://l.instagram.com/?u=http%3A%2F%2Ffeasta...
# profile_pic_url     https://scontent-hou1-1.cdninstagram.com/v/t51...
# profile_pic_url_hd  https://scontent-hou1-1.cdninstagram.com/v/t51...

# %%
df.head(40)
# Out:
#                                                                                      data
# about                                                                                 NAN
# account_badges                                                                         []
# account_type                                                                            3
# active_standalone_fundraisers                       {'fundraisers': [], 'total_count': 0}
# adjusted_banners_order                                                                 []
# ads_incentive_expiration_date                                                         NAN
# ads_page_id                                                                           NAN
# ads_page_name                                                                         NAN
# bio_links                               [{'image_url': '', 'is_pinned': False, 'is_ver...
# ...

# %%
# delete column profile_pic_url_versions	from df8

df8.drop(columns=['profile_pic_url_versions'], inplace=True)

# %% [markdown]
# **Now Checking all Dataframe , to know which dataframe contain which information and then tranposing them to concat all as one dataframe :-**

# %%
df8
# Out:
#                                                                  data
# external_lynx_url   https://l.instagram.com/?u=http%3A%2F%2Ffeasta...
# profile_pic_url     https://scontent-hou1-1.cdninstagram.com/v/t51...
# profile_pic_url_hd  https://scontent-hou1-1.cdninstagram.com/v/t51...
# 0                                                                 NaN

# %%
df6
# Out:
#    height                                                url  width
# 0     500  https://scontent-hou1-1.cdninstagram.com/v/t51...    500

# %%
df_transposed = df6.T
df_transposed
# Out:
#                                                         0
# height                                                500
# url     https://scontent-hou1-1.cdninstagram.com/v/t51...
# width                                                 500

# %%
w= pd.concat([df8,df_transposed],axis=1)
w
# Out:
#                                                                  data  \
# external_lynx_url   https://l.instagram.com/?u=http%3A%2F%2Ffeasta...
# profile_pic_url     https://scontent-hou1-1.cdninstagram.com/v/t51...
# profile_pic_url_hd  https://scontent-hou1-1.cdninstagram.com/v/t51...
# 0                                                                 NaN
# height                                                            NaN
# url                                                               NaN
# width                                                             NaN
#
#                                                                     0
# external_lynx_url                                                 NaN
# profile_pic_url                                                   NaN
# profile_pic_url_hd                                                NaN
# 0                                                                 NaN
# ...

# %%
df
# Out:
#                                                                 data
# about                                                           None
# account_badges                                                    []
# account_type                                                       3
# active_standalone_fundraisers  {'fundraisers': [], 'total_count': 0}
# adjusted_banners_order                                            []
# ...                                                              ...
# show_shoppable_feed                                            False
# third_party_downloads_enabled                                      1
# total_igtv_videos                                                  1
# upcoming_events                                                   []
# username                                                     mrbeast
#
# [72 rows x 1 columns]

# %%
trans= df4.T
trans
# Out:
#                    0
# id        9947671186
# username  feastables

# %%
trans1= df1.T
trans1
# Out:
#                                                                                        0
# image_url
# is_pinned                                                                          False
# is_verified                                                                        False
# link_id                                                                17961115826140065
# link_type                                                                       external
# lynx_url                               https://l.instagram.com/?u=http%3A%2F%2Ffeasta...
# open_external_url_with_in_app_browser                                               True
# title
# url                                                                http://feastables.com

# %%
trans2= df5.T
trans2
# Out:
#                                                         0
# height                                                500
# url     https://scontent-dfw5-2.cdninstagram.com/v/t51...
# width                                                 500

# %%
trans3= df6.T
trans3
# Out:
#                                                         0
# height                                                320
# url     https://scontent-dfw5-2.cdninstagram.com/v/t51...
# width                                                 320

# %%
concat1=pd.concat([trans, trans1, trans2, trans3], axis=0)
concat1
#concat1.reset_index(drop=True)
# Out:
#                                                                                        0
# id                                                                            9947671186
# username                                                                      feastables
# image_url
# is_pinned                                                                          False
# is_verified                                                                        False
# link_id                                                                17961115826140065
# link_type                                                                       external
# lynx_url                               https://l.instagram.com/?u=http%3A%2F%2Ffeasta...
# open_external_url_with_in_app_browser                                               True
# title
# url                                                                http://feastables.com
# ...

# %%
concat1.columns
# Out:
# Index([0], dtype='int64')

# %%
df.columns
# Out:
# Index(['data'], dtype='object')

# %%
# prompt: rename columns name 0 to 'data' in concat1

concat1.rename(columns={0: 'data'}, inplace=True)

# %%
concat1
# Out:
#                                                                                     data
# id                                                                            9947671186
# username                                                                      feastables
# image_url
# is_pinned                                                                          False
# is_verified                                                                        False
# link_id                                                                17961115826140065
# link_type                                                                       external
# lynx_url                               https://l.instagram.com/?u=http%3A%2F%2Ffeasta...
# open_external_url_with_in_app_browser                                               True
# title
# url                                                                http://feastables.com
# ...

# %% [markdown]
# **Below "concat2" is summation of all Dataframe :-**

# %%
concat2= pd.concat([df, concat1],axis=0)
concat2.tail(40)
# Out:
#                                                                                              data
# location_data                                   {'address_street': '', 'city_id': 0, 'city_nam...
# media_count                                                                                   289
# merchant_checkout_style                                                                      none
# page_id                                                                                      None
# page_name                                                                                    None
# pinned_channels_info                            {'has_public_channels': False, 'pinned_channel...
# primary_profile_link_type                                                                       0
# professional_conversion_suggested_account_type                                                  3
# profile_context
# ...

# %%
concat2.to_csv('concat2.csv')
from google.colab import files

files.download('concat2.csv')

# %%
#  check null values in concat2

nul=concat2.isnull().sum()

# %%
# null values rows in concat2

nul = concat2.isnull().sum()
null_rows = concat2[concat2.isnull().any(axis=1)]
print(null_rows)
# Out:
#                                data
# about                          None
# ads_incentive_expiration_date  None
# ads_page_id                    None
# ads_page_name                  None
# biography_email                None
# current_catalog_id             None
# page_id                        None
# page_name                      None

# %%
# prompt: replace NONE to NA in concat2

import pandas as pd

# Replace None with NA in the DataFrame
concat2.fillna('NA', inplace=True)

# Print the DataFrame
concat2.head(65)
# Out:
#                                                                             data
# about                                                                         NA
# account_badges                                                                []
# account_type                                                                   3
# active_standalone_fundraisers              {'fundraisers': [], 'total_count': 0}
# adjusted_banners_order                                                        []
# ...                                                                          ...
# profile_pic_id                                    1765328607101572916_2278169415
# profile_pic_url                https://scontent-dfw5-2.cdninstagram.com/v/t51...
# profile_pic_url_hd             https://scontent-dfw5-2.cdninstagram.com/v/t51...
# public_email
# public_phone_country_code
#
# [65 rows x 1 columns]

# %%
x1=df['data'][49]
df9=pd.DataFrame(x1, index=[0])
df9
trans4=df9.T
trans4
# Out:
#                          0
# address_street
# city_id                  0
# city_name
# instagram_location_id
# latitude               0.0
# longitude              0.0
# zip

# %%
# fill na in df9

df9.fillna('NA', inplace=True)
df9
# Out:
#   address_street  city_id city_name instagram_location_id  latitude  \
# 0                       0                                       0.0
#
#    longitude zip
# 0        0.0
